# %%
import pandas as pd
import numpy as np

# %%
columnNames = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic']
article_read = pd.read_csv('Dataset/pandas_tutorial_read.csv', delimiter=";" , names= columnNames)

# %%
article_read
# Out:
#               my_datetime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
article_read.head()
# Out:
#            my_datetime event    country     user_id   source          topic
# 0  2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1  2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2  2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3  2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4  2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America

# %%
article_read.tail()
# Out:
#               my_datetime event    country     user_id   source          topic
# 1790  2018-01-01 23:57:14  read  country_2  2458153051  AdWords  North America
# 1791  2018-01-01 23:58:33  read  country_8  2458153052      SEO           Asia
# 1792  2018-01-01 23:59:36  read  country_6  2458153053   Reddit           Asia
# 1793  2018-01-01 23:59:36  read  country_7  2458153054  AdWords         Europe
# 1794  2018-01-01 23:59:38  read  country_5  2458153055   Reddit           Asia

# %%
article_read.sample(5)
# Out:
#               my_datetime event    country     user_id   source      topic
# 1646  2018-01-01 22:11:11  read  country_5  2458152907   Reddit     Europe
# 989   2018-01-01 13:16:18  read  country_4  2458152250   Reddit  Australia
# 1338  2018-01-01 18:10:32  read  country_2  2458152599   Reddit       Asia
# 1253  2018-01-01 16:57:10  read  country_5  2458152514   Reddit       Asia
# 1121  2018-01-01 15:00:17  read  country_2  2458152382  AdWords       Asia

# %%
article_read[['country', 'user_id']]
# Out:
#         country     user_id
# 0     country_7  2458151261
# 1     country_7  2458151262
# 2     country_7  2458151263
# 3     country_7  2458151264
# 4     country_8  2458151265
# 5     country_6  2458151266
# 6     country_2  2458151267
# 7     country_6  2458151268
# 8     country_7  2458151269
# 9     country_5  2458151270
# 10    country_5  2458151271
# 11    country_7  2458151272
# 12    country_5  2458151273
# 13    country_2  2458151274
# 14    country_7  2458151275
# 15    country_7  2458151276
# 16    country_8  2458151277
# 17    country_2  2458151278
# 18    country_4  2458151279
# 19    country_2  2458151280
# 20    country_2  2458151281
# 21    country_7  2458151282
# 22    country_2  2458151283
# 23    country_2  2458151284
# 24    country_7  2458151285
# 25    country_2  2458151286
# 26    country_5  2458151287
# 27    country_2  2458151288
# 28    country_2  2458151289
# 29    country_7  2458151290
# ...         ...         ...
# 1765  country_2  2458153026
# ...

# %%
article_read.source == 'SEO'
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11       True
# 12      False
# 13      False
# 14      False
# 15       True
# 16       True
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26       True
# 27       True
# 28      False
# 29      False
#         ...
# 1765    False
# 1766    False
# 1767    False
# 1768    False
# 1769    False
# 1770    False
# 1771    False
# 1772     True
# 1773    False
# 1774    False
# 1775    False
# 1776    False
# 1777     True
# 1778    False
# 1779     True
# 1780    False
# 1781    False
# 1782    False
# 1783    False
# 1784     True
# 1785    False
# 1786    False
# 1787    False
# 1788    False
# 1789    False
# 1790    False
# 1791     True
# 1792    False
# 1793    False
# 1794    False
# ...

# %%
article_country = article_read[article_read.country == 'country_2']
article_country_filtered = article_country[['user_id', 'topic', 'country']].head()
article_country_filtered
# Out:
#        user_id   topic    country
# 6   2458151267  Europe  country_2
# 13  2458151274  Europe  country_2
# 17  2458151278    Asia  country_2
# 19  2458151280    Asia  country_2
# 20  2458151281    Asia  country_2

# %%
article_read[article_read.country == 'country_2'].groupby(['source', 'topic']).count()
# Out:
#                        my_datetime  event  country  user_id
# source  topic
# AdWords Africa                   3      3        3        3
#         Asia                    31     31       31       31
#         Australia                6      6        6        6
#         Europe                  46     46       46       46
#         North America           11     11       11       11
#         South America           14     14       14       14
# Reddit  Africa                  24     24       24       24
#         Asia                   139    139      139      139
#         Australia               18     18       18       18
#         Europe                  29     29       29       29
#         North America           27     27       27       27
#         South America           26     26       26       26
# SEO     Africa                   7      7        7        7
#         Asia                     9      9        9        9
# ...

# %%
article_read[article_read.country == 'country_2'][['user_id', 'topic', 'country']].head()
# Out:
#        user_id   topic    country
# 6   2458151267  Europe  country_2
# 13  2458151274  Europe  country_2
# 17  2458151278    Asia  country_2
# 19  2458151280    Asia  country_2
# 20  2458151281    Asia  country_2
